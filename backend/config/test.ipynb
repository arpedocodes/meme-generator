# %%
obj = """[
  {
    "left_text": "Me explaining why I need a nap after doing absolutely nothing all day",
    "right_text": "My last two brain cells agreeing with me"
  },
  {
    "left_text": "Me: I'll start eating healthy tomorrow.",
    "right_text": "Also me at 2am: Would you like your pizza with or without extra existential dread?"
  },
  {
    "left_text": "Me trying to socialize at a party:",
    "right_text": "\"So... do you also rehearse conversations in your head for fun or is that just my hobby?\""
  },
  {
    "left_text": "My anxiety: What if you mess up?",
    "right_text": "My overconfidence: Nah, we just vibe and hope for the best."
  }
]"""

# %%
type(obj)
# Out:
# str

# %%
import json

obj = '''[
  {
    "left_text": "Me explaining why I need a nap after doing absolutely nothing all day",
    "right_text": "My last two brain cells agreeing with me"
  },
  {
    "left_text": "Me: I'll start eating healthy tomorrow.",
    "right_text": "Also me at 2am: Would you like your pizza with or without extra existential dread?"
  },
  {
    "left_text": "Me trying to socialize at a party:",
    "right_text": "So... do you also rehearse conversations in your head for fun or is that just my hobby?"
  },
  {
    "left_text": "My anxiety: What if you mess up?",
    "right_text": "My overconfidence: Nah, we just vibe and hope for the best."
  }
]'''

parsed = json.loads(obj)
print(parsed)
# Out:
# [{'left_text': 'Me explaining why I need a nap after doing absolutely nothing all day', 'right_text': 'My last two brain cells agreeing with me'}, {'left_text': "Me: I'll start eating healthy tomorrow.", 'right_text': 'Also me at 2am: Would you like your pizza with or without extra existential dread?'}, {'left_text': 'Me trying to socialize at a party:', 'right_text': 'So... do you also rehearse conversations in your head for fun or is that just my hobby?'}, {'left_text': 'My anxiety: What if you mess up?', 'right_text': 'My overconfidence: Nah, we just vibe and hope for the best.'}]

# %%
text = []
for i in parsed:
    text.append(i.values(

        
    ))

# %%
for i in text:
    for j in i:
        print(j)
    print()
# Out:
# Me explaining why I need a nap after doing absolutely nothing all day
# My last two brain cells agreeing with me
#
# Me: I'll start eating healthy tomorrow.
# Also me at 2am: Would you like your pizza with or without extra existential dread?
#
# Me trying to socialize at a party:
# So... do you also rehearse conversations in your head for fun or is that just my hobby?
#
# My anxiety: What if you mess up?
# My overconfidence: Nah, we just vibe and hope for the best.

# %%
import json

# Open and read the JSON file
with open(r'C:\AI EVO (Journey)\Ai Agents\meme-generator\backend\server\data\rectangleData.json', 'r') as file:
    data = json.load(file)

# Print the data
print(data)
# Out:
# [{'id': 'rect_1747395913516', 'leftTop': {'x': 132, 'y': 111}, 'rightBottom': {'x': 313.1008492494241, 'y': 221.39999389648438}, 'width': 181.10084924942407, 'height': 110.39999389648438, 'angle': 0}, {'id': 'rect_1747395923303', 'leftTop': {'x': 494, 'y': 110.00000000000011}, 'rightBottom': {'x': 674.4512765998513, 'y': 220.39999389648438}, 'width': 180.45127659985135, 'height': 110.39999389648426, 'angle': 0}]

# %%
for i in data:
    print(tuple(i['leftTop'].values()),tuple(i['rightBottom'].values()))
# Out:
# (132, 111) (313.1008492494241, 221.39999389648438)
# (494, 110.00000000000011) (674.4512765998513, 220.39999389648438)
